# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Bruteforce004/Cleaned-data-of-Indian-Forests/main/Agricultural_Trends(2009-2015).csv")
df
# Out:
#     Unnamed: 0                                     Classification  2009-10  \
# 0            0                                  Geographical Area   328.73
# 1            1     Reporting Area for Land Utilisation Statistics   307.41
# 2            2                                             Forest    71.56
# 3            3  Not Available for Cultivation (Area Under Non-...    43.33
# 4            4                   Area Under Non-agricultural Uses    26.16
# 5            5                        Barren & Un-culturable Land    17.18
# 6            6  Other Uncultivated land excluding Fallow(Perma...    26.50
# 7            7             Permanent Pasture & other Grazing Land    10.34
# 8            8               Land under Miscellaneous Tree Crops      3.21
# 9            9                              Culturable Waste Land    12.95
# 10          10  Fallow Lands (Fallow Lands other than Current ...    26.85
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace= True)

# %%
df.drop([0,1,3,6,10], axis=0, inplace= True)

# %%
df.set_index('Classification', inplace=True)
df
# Out:
#                                          2009-10  2010-11  2011-12  2012-13  \
# Classification
# Forest                                     71.56    71.59    71.60    71.57
#  Area Under Non-agricultural Uses          26.16    26.40    26.31    26.50
# Barren & Un-culturable Land                17.18    17.18    17.22    17.07
# Permanent Pasture & other Grazing Land     10.34    10.30    10.31    10.26
# Land under Miscellaneous Tree Crops         3.21     3.20     3.16     3.18
# Culturable Waste Land                      12.95    12.65    12.64    12.64
# Fallow Lands other than Current Fallows    10.84    10.32    10.67    11.04
# Current Fallows                            16.01    14.28    14.51    15.29
# Net Area Sown                             139.17   141.56   140.98   139.94
# Total Cropped Area (Gross Cropped Area)   189.19   197.68   195.80   194.25
# Area Sown more than once\t                 50.02    56.12    54.82    54.31
# ...

# %%
df1 = df.T
df1
# Out:
# Classification  Forest   Area Under Non-agricultural Uses  \
# 2009-10          71.56                              26.16
# 2010-11          71.59                              26.40
# 2011-12          71.60                              26.31
# 2012-13          71.57                              26.50
# 2013-14          71.83                              26.91
# 2014-15          71.79                              26.88
#
# Classification  Barren & Un-culturable Land  \
# 2009-10                               17.18
# 2010-11                               17.18
# 2011-12                               17.22
# 2012-13                               17.07
# 2013-14                               16.95
# 2014-15                               17.00
#
# Classification  Permanent Pasture & other Grazing Land  \
# 2009-10                                          10.34
# 2010-11                                          10.30
# 2011-12                                          10.31
# ...

# %%
df1.columns
# Out:
# Index(['Forest', ' Area Under Non-agricultural Uses',
#        'Barren & Un-culturable Land', 'Permanent Pasture & other Grazing Land',
#        'Land under Miscellaneous Tree Crops ', 'Culturable Waste Land',
#        'Fallow Lands other than Current Fallows', 'Current Fallows',
#        'Net Area Sown ', 'Total Cropped Area (Gross Cropped Area)',
#        'Area Sown more than once\t', 'Cropping Intensity',
#        'Net Irrigated Area', 'Gross Irrigated Area'],
#       dtype='object', name='Classification')

# %%
import seaborn as sns
import pandas as pd
import numpy as np
plt.figure(figsize = (8,8))
sns.heatmap(df, fmt='g',linewidths=1,annot=True, annot_kws={"size":10}, cmap = 'crest')
plt.title("AGRICULTRAL TRENDS FOR 2019", fontsize=16)
plt.xlabel("CLASSIFICATION", fontsize = 14)
plt.ylabel("YEARS" , fontsize=14)
plt.show()
plt.close()
